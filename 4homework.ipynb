# %% [markdown]
# <a href="https://colab.research.google.com/github/rrbka69/-/blob/main/4homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Урок 4. Визуальный анализ данных**
#
#
# Условие 1: Задача 1
#
#
# Постройте график
#
# Назовите график
#
# Сделайте именование оси x и оси y
#
# Сделайте выводы

# %%
plt.hist(df['price'])
plt.title('Распределение стоимости')
plt.xlabel('Цена')
plt.ylabel('Количество');

# %% [markdown]
# *Колличество домов прямопропорционально их цене*

# %% [markdown]
# 1.1. Скачать следующие данные: kc-house-data и laptop_price
#
# 1.2. Изучите стоимости недвижимости
#
# 1.3. Изучите распределение квадратуры жилой
#
# 1.4. Изучите распределение года постройки

# %%
import pandas as pd

df = pd.read_csv('/content/kc_house_data.csv', sep=',')
df.sample(n=100)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 9139    826000495  20150206T000000  557510.0         4       2.00
# 11065  2592200030  20140618T000000  650000.0         3       1.75
# 8828    726059349  20150319T000000  460000.0         3       1.75
# 16052  9521101315  20150501T000000  600000.0         3       1.00
# 14326  2426049154  20150305T000000  412500.0         3       1.75
# ...           ...              ...       ...       ...        ...
# 15201  3396820010  20150223T000000  542000.0         3       2.25
# 2135   7967600069  20141117T000000  185000.0         3       1.00
# 11197  5647000060  20141211T000000  344950.0         3       2.00
# 12352  3226059128  20140618T000000  850000.0         5       3.50
# 4320   1887000100  20140814T000000  485000.0         5       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 9139          1580      4800     1.5           0     2  ...      7
# ...

# %%
plt.hist(df['sqft_living'])
plt.title('Распределение жилой площади')
plt.xlabel('распределение жилой квадратуры')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %% [markdown]
# *больше всего продается жилая квадраура небольших размеров*

# %%
plt.hist(df['yr_built'])
plt.title('Распределение года постройки')
plt.xlabel('год постройки')
plt.ylabel('Количество');

# %% [markdown]
# *новая недвижимость продается в больших количествах*

# %% [markdown]
# Условие 2: 2 задача
#
# 2.1. Изучите распределение домов от наличия вида на набережную.
# Постройте график.
# Сделайте выводы.

# %%
vid = df['waterfront'].value_counts()
vid.head()
# Out:
# 0    21450
# 1      163
# Name: waterfront, dtype: int64

# %%
# sns.histplot(x = df['waterfront'], y = df['price']);

plt.figure(figsize=(5, 5))
plt.hist(df['waterfront'])

plt.title('Распределение стоимости домов с видом на набережную')
plt.xlabel('наличае набережной')
plt.ylabel('Цена');

# %% [markdown]
# *Количество домов с видом на набережную меньше, чем без вида на неё*

# %% [markdown]
# 2.2. Изучите распределение этажей домов

# %%
df['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
plt.hist(df['floors'])
plt.title('Изучение распределения этажей домов')
plt.xlabel('Этажи')
plt.ylabel('Количество домов')
# Out:
# Text(0, 0.5, 'Количество домов')

# %% [markdown]
# 2.3. Изучите распределение состояния домов

# %%
df['view'].value_counts()
# Out:
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: view, dtype: int64

# %%
plt.hist(df['view'])
plt.title('Изучение распределения состояния домов')
plt.xlabel('Оценка')
plt.ylabel('Количество домов');

# %% [markdown]
# Условие 3: 3 задача
#
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
#
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
# <ipython-input-80-208d05607fc1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# ...

# %%
import seaborn as sns

plt.figure(figsize=(15, 15))
sns.heatmap(corr_matrix, annot=True, linewidths=.5, cmap='coolwarm');

# %%
sns.jointplot(x=df['sqft_living'], y=df['price'], kind='reg');

# %% [markdown]
# *дороже стоит недвижимость с большой площадью*

# %%
sns.jointplot(x=df['condition'], y=df['price'], kind='reg');

# %% [markdown]
# *чем хуже состояние, тем дешевле недвижимость*

# %%
from seaborn.widgets import plt
plt.figure(figsize=(15,8))

sns.boxplot(x=df['price'], y=df['grade'].astype('str'), whis=1.5)

plt.xlabel('price')
plt.ylabel('grade')
plt. title('Распределение цены и качества');

# %% [markdown]
# *недвижимость больше ценится с высоким качеством конструкций и дизайна*
